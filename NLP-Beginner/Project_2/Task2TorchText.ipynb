# %%
import torch
import pandas as pd
import numpy as np
import torchtext
from torchtext import data,datasets
from torchtext.vocab import GloVe
from torchtext import data
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import random
import spacy
spacy_en = spacy.load('en_core_web_sm')

def tokenizer(text): # create a tokenizer function
    return [tok.text for tok in spacy_en.tokenizer(text)]

TEXT = data.Field(sequential=True, tokenize=tokenizer, lower=True, fix_length=100)
LABEL = data.Field(sequential=False, use_vocab=False)

# %%
train_data = data.TabularDataset(
        path='./train.tsv',format='tsv',
        skip_header=True,
        fields = [('PhraseId', None),('SentenceId', None),('Phrase', TEXT),('Sentiment',LABEL)])
test_data = data.TabularDataset(
        path='./test.tsv',format='tsv',
        skip_header=True,
        fields = [('PhraseId', None),('SentenceId', None),('Phrase', TEXT)])

# %%
#vector.unk_init = init.xavier_uniform
#构建字典和batch
TEXT.build_vocab(train_data, vectors=GloVe(name='6B', dim=300))
LABEL.build_vocab()
#划分数据集
train_data, valid_data = train_data.split(random_state = random.seed(10))



#print(train_data[0].Phrase)
BATCH_SIZE = 16
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
train_iterator, valid_iterator = data.BucketIterator.splits(
    (train_data, valid_data), 
    sort_key=lambda x: len(x.Phrase), 
    batch_size = BATCH_SIZE,
    device = device)



train_on_gpu=torch.cuda.is_available()
if(train_on_gpu):
    print('Training on GPU.')
else:
    print('No GPU available, training on CPU.')


#train_iterator.__dict__.keys()
# Out:
# Training on GPU.

# %%
for idx, batch in enumerate(train_iterator):
    print(batch)
    text, label = batch.Phrase, batch.Sentiment
    print(text.shape, label.shape)
# Out:
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# ...
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 10]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x10 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 10 (GPU 0)]
# torch.Size([100, 10]) torch.Size([10])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])
#
# [torchtext.data.batch.Batch of size 16]
# 	[.Phrase]:[torch.cuda.LongTensor of size 100x16 (GPU 0)]
# 	[.Sentiment]:[torch.cuda.LongTensor of size 16 (GPU 0)]
# torch.Size([100, 16]) torch.Size([16])

# %%
class SentimentRNN(nn.Module):

    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_size,n_layers, drop_prob=0.2):
        super(SentimentRNN, self).__init__()
        self.vocab_size=vocab_size
        #self.input_size=input_size
        self.hidden_dim=hidden_dim
        self.output_size=output_size
        self.embedding_dim = embedding_dim
        self.n_layers=n_layers
        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)  
        # 若使用预训练的词向量，需在此处指定预训练的权重
        self.word_embeddings.weight.data.copy_(TEXT.vocab.vectors)
        self.word_embeddings.weight.data.requires_grad=False
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, n_layers,dropout=drop_prob)  
        self.dropout = nn.Dropout(drop_prob)
        self.decoder = nn.Linear(hidden_dim, output_size)

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)
        lstm_out = self.lstm(embeds)[0]  
        # 取最后一个时间步
        final = lstm_out[-1]  
        y = self.decoder(final)   
        return y

# %%
vocab_size = int(TEXT.vocab.vectors.shape[0]) # +1 for the 0 padding
output_size = 5
embedding_dim = 300
hidden_dim = 512
n_layers = 2

net = SentimentRNN(vocab_size,embedding_dim, hidden_dim,output_size, n_layers)

print(net)
# loss and optimization functions
optimizer = optim.Adam(filter(lambda p: p.requires_grad, net.parameters()), lr=0.001)
loss_funtion = F.cross_entropy
# Out:
# SentimentRNN(
#   (word_embeddings): Embedding(15434, 300)
#   (lstm): LSTM(300, 512, num_layers=2, dropout=0.2)
#   (dropout): Dropout(p=0.2)
#   (decoder): Linear(in_features=512, out_features=5, bias=True)
# )

# %%
epochs = 3 # 3-4 is approx where I noticed the validation loss stop decreasing

counter = 0
print_every = 100
clip=5 # gradient clipping

# move model to GPU, if available
if(train_on_gpu):
    net.cuda()

net.train()
losses=[]
# train for some number of epochs
for epoch, batch in enumerate(train_iterator):
    optimizer.zero_grad()
    #start = time.time()
    predicted = net(batch.Phrase)

    loss = loss_funtion(predicted, batch.Sentiment)
    loss.backward()
    optimizer.step()
    losses.append(loss.item())
    
    if epoch % print_every == 0:
        print("Epoch: {}/{}...".format(epoch+1,len(train_iterator)),
              "Loss: {:.6f}...".format(loss.item()),
              "Val_loss: {:.6f}...".format(np.mean(losses)))
# Out:
# Epoch: 1/6828... Loss: 1.610013... Val_loss: 1.610013...
# Epoch: 101/6828... Loss: 1.148805... Val_loss: 1.285953...
# Epoch: 201/6828... Loss: 1.508527... Val_loss: 1.300165...
# Epoch: 301/6828... Loss: 1.185259... Val_loss: 1.288648...
# Epoch: 401/6828... Loss: 1.364813... Val_loss: 1.282188...
# Epoch: 501/6828... Loss: 1.218654... Val_loss: 1.278812...
# Epoch: 601/6828... Loss: 1.446423... Val_loss: 1.285568...
# Epoch: 701/6828... Loss: 1.424707... Val_loss: 1.284740...
# Epoch: 801/6828... Loss: 1.625350... Val_loss: 1.281589...
# Epoch: 901/6828... Loss: 1.325932... Val_loss: 1.282357...
# Epoch: 1001/6828... Loss: 1.250041... Val_loss: 1.286300...
# Epoch: 1101/6828... Loss: 1.452697... Val_loss: 1.283545...
# Epoch: 1201/6828... Loss: 1.380004... Val_loss: 1.283156...
# Epoch: 1301/6828... Loss: 1.311083... Val_loss: 1.283378...
# Epoch: 1401/6828... Loss: 1.236761... Val_loss: 1.282680...
# Epoch: 1501/6828... Loss: 1.532361... Val_loss: 1.284769...
# Epoch: 1601/6828... Loss: 1.145061... Val_loss: 1.285266...
# Epoch: 1701/6828... Loss: 1.250976... Val_loss: 1.285945...
# Epoch: 1801/6828... Loss: 1.291940... Val_loss: 1.288085...
# Epoch: 1901/6828... Loss: 1.332047... Val_loss: 1.289005...
# Epoch: 2001/6828... Loss: 1.127297... Val_loss: 1.290498...
# Epoch: 2101/6828... Loss: 1.115341... Val_loss: 1.289156...
# Epoch: 2201/6828... Loss: 1.541149... Val_loss: 1.289714...
# Epoch: 2301/6828... Loss: 1.108585... Val_loss: 1.290194...
# Epoch: 2401/6828... Loss: 1.456323... Val_loss: 1.290077...
# Epoch: 2501/6828... Loss: 1.127937... Val_loss: 1.290178...
# Epoch: 2601/6828... Loss: 0.998837... Val_loss: 1.290266...
# Epoch: 2701/6828... Loss: 1.329125... Val_loss: 1.289968...
# Epoch: 2801/6828... Loss: 1.411875... Val_loss: 1.290207...
# Epoch: 2901/6828... Loss: 1.249607... Val_loss: 1.289354...
# Epoch: 3001/6828... Loss: 1.427316... Val_loss: 1.288978...
# Epoch: 3101/6828... Loss: 1.392150... Val_loss: 1.288901...
# Epoch: 3201/6828... Loss: 1.037880... Val_loss: 1.287450...
# Epoch: 3301/6828... Loss: 1.314234... Val_loss: 1.287704...
# Epoch: 3401/6828... Loss: 1.534058... Val_loss: 1.287611...
# Epoch: 3501/6828... Loss: 1.045218... Val_loss: 1.286920...
# Epoch: 3601/6828... Loss: 1.271961... Val_loss: 1.286706...
# Epoch: 3701/6828... Loss: 1.168996... Val_loss: 1.286519...
# Epoch: 3801/6828... Loss: 1.468435... Val_loss: 1.286850...
# Epoch: 3901/6828... Loss: 1.230591... Val_loss: 1.286887...
# Epoch: 4001/6828... Loss: 1.255579... Val_loss: 1.286618...
# Epoch: 4101/6828... Loss: 1.127759... Val_loss: 1.286772...
# Epoch: 4201/6828... Loss: 1.486151... Val_loss: 1.286887...
# Epoch: 4301/6828... Loss: 1.165357... Val_loss: 1.286828...
# Epoch: 4401/6828... Loss: 1.097631... Val_loss: 1.287214...
# Epoch: 4501/6828... Loss: 1.650821... Val_loss: 1.287386...
# Epoch: 4601/6828... Loss: 1.098794... Val_loss: 1.286188...
# Epoch: 4701/6828... Loss: 1.211130... Val_loss: 1.286814...
# Epoch: 4801/6828... Loss: 1.178545... Val_loss: 1.286526...
# Epoch: 4901/6828... Loss: 1.114758... Val_loss: 1.286961...
# Epoch: 5001/6828... Loss: 1.303648... Val_loss: 1.287091...
# Epoch: 5101/6828... Loss: 1.250589... Val_loss: 1.286909...
# Epoch: 5201/6828... Loss: 1.111229... Val_loss: 1.286782...
# Epoch: 5301/6828... Loss: 1.300508... Val_loss: 1.287248...
# Epoch: 5401/6828... Loss: 1.343037... Val_loss: 1.286821...
# Epoch: 5501/6828... Loss: 1.391702... Val_loss: 1.286798...
# Epoch: 5601/6828... Loss: 1.677513... Val_loss: 1.286743...
# Epoch: 5701/6828... Loss: 1.242602... Val_loss: 1.286149...
# Epoch: 5801/6828... Loss: 1.376111... Val_loss: 1.285972...
# Epoch: 5901/6828... Loss: 1.166126... Val_loss: 1.285737...
# Epoch: 6001/6828... Loss: 1.384757... Val_loss: 1.285869...
# Epoch: 6101/6828... Loss: 1.400720... Val_loss: 1.285478...
# Epoch: 6201/6828... Loss: 1.465785... Val_loss: 1.285552...
# Epoch: 6301/6828... Loss: 1.245856... Val_loss: 1.286522...
# Epoch: 6401/6828... Loss: 1.382085... Val_loss: 1.286873...
# Epoch: 6501/6828... Loss: 1.542957... Val_loss: 1.286968...
# Epoch: 6601/6828... Loss: 1.202126... Val_loss: 1.286725...
# Epoch: 6701/6828... Loss: 1.418531... Val_loss: 1.287108...
# Epoch: 6801/6828... Loss: 1.215538... Val_loss: 1.286820...

# %%
net.train()
valid_losses=[]
num_correct = 0
# train for some number of epochs
for epoch, batch in enumerate(valid_iterator):
    optimizer.zero_grad()
    #start = time.time()
    predicted = net(batch.Phrase)

    valid_loss = loss_funtion(predicted, batch.Sentiment)
    valid_losses.append(valid_loss.item())
    #loss.backward()
    #optimizer.step()
    _, pred = torch.max(predicted,1)
    # Get test data loss and accuracy
    correct_tensor = pred.eq(batch.Sentiment.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    num_correct += np.sum(correct)

# -- stats! -- ##
# avg test loss
print("Test loss: {:.3f}".format(np.mean(valid_losses)))

# accuracy over all test data
test_acc = num_correct/len(valid_iterator.dataset)
print("Test accuracy: {:.3f}".format(test_acc))
